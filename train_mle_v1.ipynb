# %%
import torch
import torch.nn as nn
import logging
from tensorboardX import SummaryWriter
import onmt.translate
from metrics import BleuScore, CorrectAnswersScore
from trainer import SimMLETrainer
# Out:
# /home/galprz/miniconda3/envs/simv2/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /home/galprz/miniconda3/envs/simv2/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit

# %%
mode="v1"
writer = SummaryWriter(comment="-argmax")
fmt = "%(asctime)-15s %(levelname)s %(message)s"
logging.basicConfig(format=fmt, level=logging.INFO)
scenario_number = 8
vocab_fields = torch.load(f"processed/SimQA.vocab.pt")

src_text_field = vocab_fields["src"].base_field
src_vocab = src_text_field.vocab
src_padding = src_vocab.stoi[src_text_field.pad_token]

tgt_text_field = vocab_fields['tgt'].base_field
tgt_vocab = tgt_text_field.vocab
tgt_padding = tgt_vocab.stoi[tgt_text_field.pad_token]

emb_size = 200
rnn_size = 200
encoder_embeddings = onmt.modules.Embeddings(
    emb_size,
    len(src_vocab),
    word_padding_idx=src_padding,
    position_encoding=True,
    fix_word_vecs=True)
encoder_embeddings.load_pretrained_vectors(f"src.embeddings.pt")


encoder = onmt.encoders.TransformerEncoder(
    num_layers=6,
    d_model=emb_size,
    max_relative_positions=100,
    embeddings=encoder_embeddings,
    d_ff=1,
    dropout=0.1,
    attention_dropout=0.1,
    heads=8
)

decoder_embeddings = onmt.modules.Embeddings(emb_size,
                                             len(tgt_vocab),
                                             word_padding_idx=tgt_padding,
                                             position_encoding=True)
decoder = onmt.decoders.TransformerDecoder(
    num_layers=6,
    d_model=emb_size,
    embeddings=decoder_embeddings,
    max_relative_positions=100,
    aan_useffn=False,
    full_context_alignment=True,
    alignment_layer=1,
    alignment_heads=1,
    heads=8,
    d_ff=1,
    copy_attn=False,
    self_attn_type="scaled-dot",
    dropout=0.1,
    attention_dropout=0.1
)

device = "cuda" if torch.cuda.is_available() else "cpu"
model = onmt.models.model.NMTModel(encoder, decoder)
model.to(device)
logging.getLogger().info(device)
# Specify the tgt word generator and loss computation module
model.generator = nn.Sequential(
    nn.Linear(emb_size, len(tgt_vocab)),
    nn.LogSoftmax(dim=-1)).to(device)

#checkpoint = torch.load("./models/model_step_5000.pt")
#model.load_state_dict(checkpoint["model"], strict=False)
#model.generator.load_state_dict(checkpoint["generator"], strict=False)

import onmt.utils.loss
loss = onmt.utils.loss.NMTLossCompute(
    criterion=nn.NLLLoss(ignore_index=tgt_padding, reduction="sum"),
    generator=model.generator)
# Out:
# 2020-11-07 20:58:50,907 INFO cuda

# %%
import onmt.opts
lr = 0.001
torch_optimizer = torch.optim.Adam(model.parameters(), lr=lr)
optim = onmt.utils.optimizers.Optimizer(
torch_optimizer, learning_rate=lr, max_grad_norm=2)

# %%
from itertools import chain
train_data_file = f"processed/SimQA.train.0.pt"
valid_data_file = f"processed/SimQA.valid.0.pt"
train_iter = onmt.inputters.inputter.DatasetLazyIter(dataset_paths=[train_data_file],
                                                     fields=vocab_fields,
                                                     batch_size=32,
                                                     batch_size_multiple=1,
                                                     batch_size_fn=None,
                                                     device=device,
                                                     is_train=True,
                                                     repeat=True,
                                                     pool_factor=8192)

valid_iter = onmt.inputters.inputter.DatasetLazyIter(dataset_paths=[valid_data_file],
                                                     fields=vocab_fields,
                                                     batch_size=16,
                                                     batch_size_multiple=1,
                                                     batch_size_fn=None,
                                                     device=device,
                                                     is_train=False,
                                                     repeat=False,
                                                     pool_factor=8192)
report_manager = onmt.utils.ReportMgr(report_every=100, tensorboard_writer=writer)

src_reader = onmt.inputters.str2reader["text"]
tgt_reader = onmt.inputters.str2reader["text"]
scorer = onmt.translate.GNMTGlobalScorer(alpha=0.7,
                                         beta=0.,
                                         length_penalty="avg",
                                         coverage_penalty="none")
gpu = 0 if torch.cuda.is_available() else -1
translator = onmt.translate.Translator(model=model,
                                       fields=vocab_fields,
                                       src_reader=src_reader,
                                       tgt_reader=tgt_reader,
                                       global_scorer=scorer,
                                       gpu=gpu)
builder = onmt.translate.TranslationBuilder(data=torch.load(valid_data_file),
                                            fields=vocab_fields, has_tgt=True)

metrics = [BleuScore(), CorrectAnswersScore(tgt_vocab)]
model_saver = onmt.models.model_saver.ModelSaver("model", model, None, vocab_fields, optim)
trainer = SimMLETrainer(model=model,
                    model_saver=model_saver,
                    train_loss=loss,
                    valid_loss=loss,
                    optim=optim,
                    report_manager=report_manager,
                    metrics=metrics,
                    translator=translator,
                    translation_builder=builder)
stats, metrics = trainer.train(train_iter=train_iter,
              src_vocab=src_vocab,
              train_steps=10000,
              valid_iter=valid_iter,
              valid_steps=100,
              save_checkpoint_steps=1000)
# Out:
# 2020-11-07 20:58:50,989 INFO Start training loop and validate every 100 steps...
# 2020-11-07 20:58:50,990 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 20:58:51,048 INFO number of examples: 3148
# 2020-11-07 20:59:23,525 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 20:59:23,584 INFO number of examples: 3148
# 2020-11-07 20:59:23,766 INFO Step 100/10000; acc:  69.01; ppl:  2.99; xent: 1.09; lr: 0.00100; 21983/6291 tok/s;     33 sec
# 2020-11-07 20:59:23,769 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 20:59:23,789 INFO number of examples: 555
# /opt/conda/conda-bld/pytorch_1591914855613/work/aten/src/ATen/native/BinaryOps.cpp:66: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# 2020-11-07 21:01:03,169 INFO Validation metrics: Bleu: 0.7513,Correct answers 0.1256, State transitions score: 0.0102
# 2020-11-07 21:01:03,170 INFO Validation perplexity: 1.56419
# 2020-11-07 21:01:03,170 INFO Validation accuracy: 85.2859
# 2020-11-07 21:01:22,018 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:01:22,078 INFO number of examples: 3148
# 2020-11-07 21:01:22,579 INFO Step 200/10000; acc:  85.92; ppl:  1.53; xent: 0.42; lr: 0.00100; 6095/1735 tok/s;    152 sec
# 2020-11-07 21:01:22,580 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:01:22,591 INFO number of examples: 555
# 2020-11-07 21:02:57,676 INFO Validation metrics: Bleu: 0.7929,Correct answers 0.0794, State transitions score: 0.0321
# 2020-11-07 21:02:57,677 INFO Validation perplexity: 1.47092
# 2020-11-07 21:02:57,677 INFO Validation accuracy: 86.5703
# 2020-11-07 21:03:16,409 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:03:16,469 INFO number of examples: 3148
# 2020-11-07 21:03:17,241 INFO Step 300/10000; acc:  86.82; ppl:  1.47; xent: 0.38; lr: 0.00100; 6271/1787 tok/s;    266 sec
# 2020-11-07 21:03:17,243 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:03:17,260 INFO number of examples: 555
# 2020-11-07 21:04:54,023 INFO Validation metrics: Bleu: 0.8332,Correct answers 0.0758, State transitions score: 0.0333
# 2020-11-07 21:04:54,024 INFO Validation perplexity: 1.43479
# 2020-11-07 21:04:54,025 INFO Validation accuracy: 87.3249
# 2020-11-07 21:05:26,554 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:05:26,609 INFO number of examples: 3148
# 2020-11-07 21:05:27,588 INFO Step 400/10000; acc:  87.57; ppl:  1.43; xent: 0.36; lr: 0.00100; 5520/1582 tok/s;    397 sec
# 2020-11-07 21:05:27,590 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:05:27,602 INFO number of examples: 555
# 2020-11-07 21:07:01,169 INFO Validation metrics: Bleu: 0.8557,Correct answers 0.1328, State transitions score: 0.0363
# 2020-11-07 21:07:01,170 INFO Validation perplexity: 1.40268
# 2020-11-07 21:07:01,171 INFO Validation accuracy: 88.0156
# 2020-11-07 21:07:19,457 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:07:19,513 INFO number of examples: 3148
# 2020-11-07 21:07:20,492 INFO Step 500/10000; acc:  88.56; ppl:  1.39; xent: 0.33; lr: 0.00100; 6371/1825 tok/s;    510 sec
# 2020-11-07 21:07:20,494 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:07:20,504 INFO number of examples: 555
# 2020-11-07 21:08:52,862 INFO Validation metrics: Bleu: 0.8631,Correct answers 0.1203, State transitions score: 0.0462
# 2020-11-07 21:08:52,863 INFO Validation perplexity: 1.33403
# 2020-11-07 21:08:52,863 INFO Validation accuracy: 89.8133
# 2020-11-07 21:09:11,298 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:09:11,361 INFO number of examples: 3148
# 2020-11-07 21:09:12,599 INFO Step 600/10000; acc:  91.65; ppl:  1.29; xent: 0.25; lr: 0.00100; 6426/1838 tok/s;    622 sec
# 2020-11-07 21:09:12,601 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:09:12,614 INFO number of examples: 555
# 2020-11-07 21:10:46,238 INFO Validation metrics: Bleu: 0.9221,Correct answers 0.1578, State transitions score: 0.0877
# 2020-11-07 21:10:46,239 INFO Validation perplexity: 1.21522
# 2020-11-07 21:10:46,240 INFO Validation accuracy: 93.7609
# 2020-11-07 21:11:04,446 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:11:04,499 INFO number of examples: 3148
# 2020-11-07 21:11:05,930 INFO Step 700/10000; acc:  94.74; ppl:  1.19; xent: 0.17; lr: 0.00100; 6372/1818 tok/s;    735 sec
# 2020-11-07 21:11:05,932 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:11:05,945 INFO number of examples: 555
# 2020-11-07 21:12:40,209 INFO Validation metrics: Bleu: 0.9445,Correct answers 0.2006, State transitions score: 0.1821
# 2020-11-07 21:12:40,210 INFO Validation perplexity: 1.14035
# 2020-11-07 21:12:40,211 INFO Validation accuracy: 95.9775
# 2020-11-07 21:12:57,983 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:12:58,041 INFO number of examples: 3148
# 2020-11-07 21:12:59,705 INFO Step 800/10000; acc:  95.94; ppl:  1.14; xent: 0.13; lr: 0.00100; 6336/1811 tok/s;    849 sec
# 2020-11-07 21:12:59,708 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:12:59,719 INFO number of examples: 555
# 2020-11-07 21:14:34,146 INFO Validation metrics: Bleu: 0.9602,Correct answers 0.2443, State transitions score: 0.2552
# 2020-11-07 21:14:34,147 INFO Validation perplexity: 1.10683
# 2020-11-07 21:14:34,147 INFO Validation accuracy: 96.8097
# 2020-11-07 21:14:51,713 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:14:51,768 INFO number of examples: 3148
# 2020-11-07 21:14:53,670 INFO Step 900/10000; acc:  96.98; ppl:  1.10; xent: 0.10; lr: 0.00100; 6308/1807 tok/s;    963 sec
# 2020-11-07 21:14:53,672 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:14:53,684 INFO number of examples: 555
# 2020-11-07 21:16:28,001 INFO Validation metrics: Bleu: 0.9646,Correct answers 0.4469, State transitions score: 0.4611
# 2020-11-07 21:16:28,002 INFO Validation perplexity: 1.07034
# 2020-11-07 21:16:28,002 INFO Validation accuracy: 97.9887
# 2020-11-07 21:16:45,442 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:16:45,499 INFO number of examples: 3148
# 2020-11-07 21:16:47,411 INFO Step 1000/10000; acc:  98.07; ppl:  1.07; xent: 0.07; lr: 0.00100; 6338/1814 tok/s;   1076 sec
# 2020-11-07 21:16:47,413 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:16:47,424 INFO number of examples: 555
# 2020-11-07 21:18:22,546 INFO Validation metrics: Bleu: 0.9850,Correct answers 0.6019, State transitions score: 0.6217
# 2020-11-07 21:18:22,547 INFO Validation perplexity: 1.03931
# 2020-11-07 21:18:22,548 INFO Validation accuracy: 98.9625
# 2020-11-07 21:18:22,560 INFO Saving checkpoint model_step_1000.pt
# 2020-11-07 21:18:39,920 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:18:39,975 INFO number of examples: 3148
# 2020-11-07 21:18:42,135 INFO Step 1100/10000; acc:  98.66; ppl:  1.05; xent: 0.05; lr: 0.00100; 6294/1798 tok/s;   1191 sec
# 2020-11-07 21:18:42,137 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:18:42,147 INFO number of examples: 555
# 2020-11-07 21:20:17,022 INFO Validation metrics: Bleu: 0.9850,Correct answers 0.6706, State transitions score: 0.6856
# 2020-11-07 21:20:17,023 INFO Validation perplexity: 1.03159
# 2020-11-07 21:20:17,023 INFO Validation accuracy: 99.1067
# 2020-11-07 21:20:33,982 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:20:34,037 INFO number of examples: 3148
# 2020-11-07 21:20:36,510 INFO Step 1200/10000; acc:  98.92; ppl:  1.04; xent: 0.04; lr: 0.00100; 6299/1802 tok/s;   1306 sec
# 2020-11-07 21:20:36,512 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:20:36,525 INFO number of examples: 555
# 2020-11-07 21:22:11,951 INFO Validation metrics: Bleu: 0.9876,Correct answers 0.6627, State transitions score: 0.6732
# 2020-11-07 21:22:11,952 INFO Validation perplexity: 1.02926
# 2020-11-07 21:22:11,952 INFO Validation accuracy: 99.1067
# 2020-11-07 21:22:28,784 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:22:28,840 INFO number of examples: 3148
# 2020-11-07 21:22:31,454 INFO Step 1300/10000; acc:  99.14; ppl:  1.03; xent: 0.03; lr: 0.00100; 6306/1793 tok/s;   1420 sec
# 2020-11-07 21:22:31,456 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:22:31,470 INFO number of examples: 555
# 2020-11-07 21:24:06,828 INFO Validation metrics: Bleu: 0.9900,Correct answers 0.7188, State transitions score: 0.7314
# 2020-11-07 21:24:06,829 INFO Validation perplexity: 1.02365
# 2020-11-07 21:24:06,830 INFO Validation accuracy: 99.3203
# 2020-11-07 21:24:23,130 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:24:23,189 INFO number of examples: 3148
# 2020-11-07 21:24:25,940 INFO Step 1400/10000; acc:  99.30; ppl:  1.02; xent: 0.02; lr: 0.00100; 6293/1800 tok/s;   1535 sec
# 2020-11-07 21:24:25,942 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:24:25,952 INFO number of examples: 555
# 2020-11-07 21:26:01,198 INFO Validation metrics: Bleu: 0.9920,Correct answers 0.7555, State transitions score: 0.7807
# 2020-11-07 21:26:01,199 INFO Validation perplexity: 1.01944
# 2020-11-07 21:26:01,199 INFO Validation accuracy: 99.4868
# 2020-11-07 21:26:17,480 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:26:17,538 INFO number of examples: 3148
# 2020-11-07 21:26:20,403 INFO Step 1500/10000; acc:  99.41; ppl:  1.02; xent: 0.02; lr: 0.00100; 6317/1803 tok/s;   1649 sec
# 2020-11-07 21:26:20,405 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:26:20,418 INFO number of examples: 555
# 2020-11-07 21:27:56,843 INFO Validation metrics: Bleu: 0.9927,Correct answers 0.7706, State transitions score: 0.7971
# 2020-11-07 21:27:56,844 INFO Validation perplexity: 1.01832
# 2020-11-07 21:27:56,845 INFO Validation accuracy: 99.4979
# 2020-11-07 21:28:13,032 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:28:13,087 INFO number of examples: 3148
# 2020-11-07 21:28:16,218 INFO Step 1600/10000; acc:  99.46; ppl:  1.02; xent: 0.02; lr: 0.00100; 6219/1779 tok/s;   1765 sec
# 2020-11-07 21:28:16,220 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:28:16,235 INFO number of examples: 555
# 2020-11-07 21:29:51,996 INFO Validation metrics: Bleu: 0.9936,Correct answers 0.8153, State transitions score: 0.8333
# 2020-11-07 21:29:51,998 INFO Validation perplexity: 1.01738
# 2020-11-07 21:29:51,998 INFO Validation accuracy: 99.6227
# 2020-11-07 21:30:08,218 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:30:08,271 INFO number of examples: 3148
# 2020-11-07 21:30:11,567 INFO Step 1700/10000; acc:  99.53; ppl:  1.02; xent: 0.02; lr: 0.00100; 6243/1787 tok/s;   1881 sec
# 2020-11-07 21:30:11,569 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:30:11,580 INFO number of examples: 555
# 2020-11-07 21:31:47,123 INFO Validation metrics: Bleu: 0.9943,Correct answers 0.8081, State transitions score: 0.8262
# 2020-11-07 21:31:47,124 INFO Validation perplexity: 1.01555
# 2020-11-07 21:31:47,124 INFO Validation accuracy: 99.5894
# 2020-11-07 21:32:03,131 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:32:03,192 INFO number of examples: 3148
# 2020-11-07 21:32:06,768 INFO Step 1800/10000; acc:  99.57; ppl:  1.01; xent: 0.01; lr: 0.00100; 6281/1792 tok/s;   1996 sec
# 2020-11-07 21:32:06,770 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:32:06,783 INFO number of examples: 555
# 2020-11-07 21:33:43,183 INFO Validation metrics: Bleu: 0.9929,Correct answers 0.8055, State transitions score: 0.8236
# 2020-11-07 21:33:43,184 INFO Validation perplexity: 1.01528
# 2020-11-07 21:33:43,185 INFO Validation accuracy: 99.5977
# 2020-11-07 21:33:58,702 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:33:58,762 INFO number of examples: 3148
# 2020-11-07 21:34:02,983 INFO Step 1900/10000; acc:  99.63; ppl:  1.01; xent: 0.01; lr: 0.00100; 6205/1774 tok/s;   2112 sec
# 2020-11-07 21:34:02,985 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:34:02,997 INFO number of examples: 555
# 2020-11-07 21:35:39,369 INFO Validation metrics: Bleu: 0.9943,Correct answers 0.8063, State transitions score: 0.8283
# 2020-11-07 21:35:39,370 INFO Validation perplexity: 1.01404
# 2020-11-07 21:35:39,370 INFO Validation accuracy: 99.6338
# 2020-11-07 21:35:54,744 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:35:54,801 INFO number of examples: 3148
# 2020-11-07 21:35:58,790 INFO Step 2000/10000; acc:  99.66; ppl:  1.01; xent: 0.01; lr: 0.00100; 6229/1781 tok/s;   2228 sec
# 2020-11-07 21:35:58,792 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:35:58,808 INFO number of examples: 555
# 2020-11-07 21:37:34,827 INFO Validation metrics: Bleu: 0.9929,Correct answers 0.8081, State transitions score: 0.8309
# 2020-11-07 21:37:34,828 INFO Validation perplexity: 1.01402
# 2020-11-07 21:37:34,828 INFO Validation accuracy: 99.6366
# 2020-11-07 21:37:34,839 INFO Saving checkpoint model_step_2000.pt
# 2020-11-07 21:37:50,198 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:37:50,257 INFO number of examples: 3148
# 2020-11-07 21:37:54,510 INFO Step 2100/10000; acc:  99.68; ppl:  1.01; xent: 0.01; lr: 0.00100; 6234/1782 tok/s;   2344 sec
# 2020-11-07 21:37:54,512 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:37:54,530 INFO number of examples: 555
# 2020-11-07 21:39:31,192 INFO Validation metrics: Bleu: 0.9937,Correct answers 0.8063, State transitions score: 0.8316
# 2020-11-07 21:39:31,193 INFO Validation perplexity: 1.01403
# 2020-11-07 21:39:31,194 INFO Validation accuracy: 99.6671
# 2020-11-07 21:39:45,992 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:39:46,053 INFO number of examples: 3148
# 2020-11-07 21:39:50,386 INFO Step 2200/10000; acc:  99.70; ppl:  1.01; xent: 0.01; lr: 0.00100; 6223/1781 tok/s;   2459 sec
# 2020-11-07 21:39:50,388 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:39:50,407 INFO number of examples: 555
# 2020-11-07 21:41:27,052 INFO Validation metrics: Bleu: 0.9960,Correct answers 0.8412, State transitions score: 0.8586
# 2020-11-07 21:41:27,053 INFO Validation perplexity: 1.01172
# 2020-11-07 21:41:27,053 INFO Validation accuracy: 99.742
# 2020-11-07 21:41:41,917 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:41:41,975 INFO number of examples: 3148
# 2020-11-07 21:41:46,579 INFO Step 2300/10000; acc:  99.73; ppl:  1.01; xent: 0.01; lr: 0.00100; 6217/1774 tok/s;   2576 sec
# 2020-11-07 21:41:46,581 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:41:46,593 INFO number of examples: 555
# 2020-11-07 21:43:23,386 INFO Validation metrics: Bleu: 0.9938,Correct answers 0.8117, State transitions score: 0.8403
# 2020-11-07 21:43:23,387 INFO Validation perplexity: 1.01321
# 2020-11-07 21:43:23,387 INFO Validation accuracy: 99.6782
# 2020-11-07 21:43:38,049 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:43:38,107 INFO number of examples: 3148
# 2020-11-07 21:43:42,971 INFO Step 2400/10000; acc:  99.74; ppl:  1.01; xent: 0.01; lr: 0.00100; 6202/1772 tok/s;   2692 sec
# 2020-11-07 21:43:42,973 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:43:42,989 INFO number of examples: 555
# 2020-11-07 21:45:19,834 INFO Validation metrics: Bleu: 0.9949,Correct answers 0.8446, State transitions score: 0.8596
# 2020-11-07 21:45:19,835 INFO Validation perplexity: 1.0114
# 2020-11-07 21:45:19,835 INFO Validation accuracy: 99.7476
# 2020-11-07 21:45:34,055 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:45:34,115 INFO number of examples: 3148
# 2020-11-07 21:45:39,075 INFO Step 2500/10000; acc:  99.75; ppl:  1.01; xent: 0.01; lr: 0.00100; 6215/1776 tok/s;   2808 sec
# 2020-11-07 21:45:39,077 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:45:39,095 INFO number of examples: 555
# 2020-11-07 21:47:16,386 INFO Validation metrics: Bleu: 0.9950,Correct answers 0.8339, State transitions score: 0.8488
# 2020-11-07 21:47:16,387 INFO Validation perplexity: 1.01123
# 2020-11-07 21:47:16,388 INFO Validation accuracy: 99.7087
# 2020-11-07 21:47:31,147 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:47:31,205 INFO number of examples: 3148
# 2020-11-07 21:47:36,257 INFO Step 2600/10000; acc:  99.79; ppl:  1.01; xent: 0.01; lr: 0.00100; 6160/1760 tok/s;   2925 sec
# 2020-11-07 21:47:36,259 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:47:36,271 INFO number of examples: 555
# 2020-11-07 21:49:13,356 INFO Validation metrics: Bleu: 0.9956,Correct answers 0.8260, State transitions score: 0.8557
# 2020-11-07 21:49:13,357 INFO Validation perplexity: 1.0121
# 2020-11-07 21:49:13,357 INFO Validation accuracy: 99.7309
# 2020-11-07 21:49:27,274 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:49:27,326 INFO number of examples: 3148
# 2020-11-07 21:49:32,663 INFO Step 2700/10000; acc:  99.76; ppl:  1.01; xent: 0.01; lr: 0.00100; 6208/1771 tok/s;   3042 sec
# 2020-11-07 21:49:32,665 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:49:32,678 INFO number of examples: 555
# 2020-11-07 21:51:09,563 INFO Validation metrics: Bleu: 0.9949,Correct answers 0.8313, State transitions score: 0.8593
# 2020-11-07 21:51:09,564 INFO Validation perplexity: 1.01216
# 2020-11-07 21:51:09,565 INFO Validation accuracy: 99.7531
# 2020-11-07 21:51:23,228 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:51:23,285 INFO number of examples: 3148
# 2020-11-07 21:51:28,908 INFO Step 2800/10000; acc:  99.80; ppl:  1.01; xent: 0.01; lr: 0.00100; 6221/1776 tok/s;   3158 sec
# 2020-11-07 21:51:28,910 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:51:28,923 INFO number of examples: 555
# 2020-11-07 21:53:06,872 INFO Validation metrics: Bleu: 0.9937,Correct answers 0.8394, State transitions score: 0.8645
# 2020-11-07 21:53:06,874 INFO Validation perplexity: 1.01355
# 2020-11-07 21:53:06,874 INFO Validation accuracy: 99.7392
# 2020-11-07 21:53:20,273 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:53:20,330 INFO number of examples: 3148
# 2020-11-07 21:53:26,087 INFO Step 2900/10000; acc:  99.80; ppl:  1.01; xent: 0.01; lr: 0.00100; 6167/1760 tok/s;   3275 sec
# 2020-11-07 21:53:26,089 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:53:26,099 INFO number of examples: 555
# 2020-11-07 21:55:03,769 INFO Validation metrics: Bleu: 0.9959,Correct answers 0.8357, State transitions score: 0.8634
# 2020-11-07 21:55:03,770 INFO Validation perplexity: 1.01226
# 2020-11-07 21:55:03,771 INFO Validation accuracy: 99.7448
# 2020-11-07 21:55:16,902 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:55:16,956 INFO number of examples: 3148
# 2020-11-07 21:55:22,902 INFO Step 3000/10000; acc:  99.83; ppl:  1.01; xent: 0.01; lr: 0.00100; 6178/1766 tok/s;   3392 sec
# 2020-11-07 21:55:22,904 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:55:22,914 INFO number of examples: 555
# 2020-11-07 21:56:59,679 INFO Validation metrics: Bleu: 0.9963,Correct answers 0.8429, State transitions score: 0.8633
# 2020-11-07 21:56:59,680 INFO Validation perplexity: 1.01105
# 2020-11-07 21:56:59,680 INFO Validation accuracy: 99.7781
# 2020-11-07 21:56:59,692 INFO Saving checkpoint model_step_3000.pt
# 2020-11-07 21:57:13,354 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:57:13,407 INFO number of examples: 3148
# 2020-11-07 21:57:19,656 INFO Step 3100/10000; acc:  99.82; ppl:  1.01; xent: 0.01; lr: 0.00100; 6185/1766 tok/s;   3509 sec
# 2020-11-07 21:57:19,658 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:57:19,670 INFO number of examples: 555
# 2020-11-07 21:58:55,823 INFO Validation metrics: Bleu: 0.9955,Correct answers 0.8278, State transitions score: 0.8616
# 2020-11-07 21:58:55,824 INFO Validation perplexity: 1.01152
# 2020-11-07 21:58:55,825 INFO Validation accuracy: 99.7309
# 2020-11-07 21:59:09,269 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 21:59:09,325 INFO number of examples: 3148
# 2020-11-07 21:59:15,637 INFO Step 3200/10000; acc:  99.84; ppl:  1.01; xent: 0.01; lr: 0.00100; 6232/1779 tok/s;   3625 sec
# 2020-11-07 21:59:15,639 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 21:59:15,653 INFO number of examples: 555
# 2020-11-07 22:00:52,173 INFO Validation metrics: Bleu: 0.9962,Correct answers 0.8474, State transitions score: 0.8721
# 2020-11-07 22:00:52,174 INFO Validation perplexity: 1.01146
# 2020-11-07 22:00:52,174 INFO Validation accuracy: 99.7836
# 2020-11-07 22:01:05,183 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:01:05,241 INFO number of examples: 3148
# 2020-11-07 22:01:11,702 INFO Step 3300/10000; acc:  99.83; ppl:  1.01; xent: 0.01; lr: 0.00100; 6217/1777 tok/s;   3741 sec
# 2020-11-07 22:01:11,705 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:01:11,716 INFO number of examples: 555
# 2020-11-07 22:02:47,434 INFO Validation metrics: Bleu: 0.9964,Correct answers 0.8518, State transitions score: 0.8712
# 2020-11-07 22:02:47,435 INFO Validation perplexity: 1.01254
# 2020-11-07 22:02:47,435 INFO Validation accuracy: 99.7753
# 2020-11-07 22:02:59,757 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:02:59,816 INFO number of examples: 3148
# 2020-11-07 22:03:06,665 INFO Step 3400/10000; acc:  99.85; ppl:  1.01; xent: 0.01; lr: 0.00100; 6288/1794 tok/s;   3856 sec
# 2020-11-07 22:03:06,667 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:03:06,681 INFO number of examples: 555
# 2020-11-07 22:04:44,270 INFO Validation metrics: Bleu: 0.9965,Correct answers 0.8482, State transitions score: 0.8674
# 2020-11-07 22:04:44,271 INFO Validation perplexity: 1.01085
# 2020-11-07 22:04:44,272 INFO Validation accuracy: 99.7753
# 2020-11-07 22:04:56,461 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:04:56,519 INFO number of examples: 3148
# 2020-11-07 22:05:03,726 INFO Step 3500/10000; acc:  99.85; ppl:  1.01; xent: 0.01; lr: 0.00100; 6148/1761 tok/s;   3973 sec
# 2020-11-07 22:05:03,728 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:05:03,740 INFO number of examples: 555
# 2020-11-07 22:06:41,091 INFO Validation metrics: Bleu: 0.9967,Correct answers 0.8500, State transitions score: 0.8779
# 2020-11-07 22:06:41,092 INFO Validation perplexity: 1.01054
# 2020-11-07 22:06:41,092 INFO Validation accuracy: 99.7919
# 2020-11-07 22:06:53,163 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:06:53,215 INFO number of examples: 3148
# 2020-11-07 22:07:00,476 INFO Step 3600/10000; acc:  99.87; ppl:  1.00; xent: 0.00; lr: 0.00100; 6196/1766 tok/s;   4089 sec
# 2020-11-07 22:07:00,478 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:07:00,490 INFO number of examples: 555
# 2020-11-07 22:08:38,784 INFO Validation metrics: Bleu: 0.9968,Correct answers 0.8554, State transitions score: 0.8779
# 2020-11-07 22:08:38,785 INFO Validation perplexity: 1.01127
# 2020-11-07 22:08:38,785 INFO Validation accuracy: 99.8086
# 2020-11-07 22:08:50,577 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:08:50,636 INFO number of examples: 3148
# 2020-11-07 22:08:58,061 INFO Step 3700/10000; acc:  99.85; ppl:  1.01; xent: 0.01; lr: 0.00100; 6124/1754 tok/s;   4207 sec
# 2020-11-07 22:08:58,062 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:08:58,076 INFO number of examples: 555
# 2020-11-07 22:10:34,806 INFO Validation metrics: Bleu: 0.9956,Correct answers 0.8474, State transitions score: 0.8623
# 2020-11-07 22:10:34,807 INFO Validation perplexity: 1.01173
# 2020-11-07 22:10:34,807 INFO Validation accuracy: 99.7725
# 2020-11-07 22:10:46,429 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:10:46,486 INFO number of examples: 3148
# 2020-11-07 22:10:54,083 INFO Step 3800/10000; acc:  99.85; ppl:  1.01; xent: 0.01; lr: 0.00100; 6204/1777 tok/s;   4323 sec
# 2020-11-07 22:10:54,085 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:10:54,098 INFO number of examples: 555
# 2020-11-07 22:12:30,397 INFO Validation metrics: Bleu: 0.9967,Correct answers 0.8545, State transitions score: 0.8739
# 2020-11-07 22:12:30,398 INFO Validation perplexity: 1.01046
# 2020-11-07 22:12:30,398 INFO Validation accuracy: 99.8114
# 2020-11-07 22:12:41,785 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:12:41,840 INFO number of examples: 3148
# 2020-11-07 22:12:49,552 INFO Step 3900/10000; acc:  99.88; ppl:  1.00; xent: 0.00; lr: 0.00100; 6237/1785 tok/s;   4439 sec
# 2020-11-07 22:12:49,554 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:12:49,565 INFO number of examples: 555
# 2020-11-07 22:14:25,856 INFO Validation metrics: Bleu: 0.9960,Correct answers 0.8554, State transitions score: 0.8836
# 2020-11-07 22:14:25,857 INFO Validation perplexity: 1.0122
# 2020-11-07 22:14:25,857 INFO Validation accuracy: 99.7836
# 2020-11-07 22:14:37,061 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:14:37,119 INFO number of examples: 3148
# 2020-11-07 22:14:45,105 INFO Step 4000/10000; acc:  99.87; ppl:  1.00; xent: 0.00; lr: 0.00100; 6251/1784 tok/s;   4554 sec
# 2020-11-07 22:14:45,107 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:14:45,121 INFO number of examples: 555
# 2020-11-07 22:16:21,330 INFO Validation metrics: Bleu: 0.9961,Correct answers 0.8518, State transitions score: 0.8765
# 2020-11-07 22:16:21,331 INFO Validation perplexity: 1.01267
# 2020-11-07 22:16:21,332 INFO Validation accuracy: 99.8003
# 2020-11-07 22:16:21,343 INFO Saving checkpoint model_step_4000.pt
# 2020-11-07 22:16:32,549 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:16:32,604 INFO number of examples: 3148
# 2020-11-07 22:16:40,694 INFO Step 4100/10000; acc:  99.88; ppl:  1.00; xent: 0.00; lr: 0.00100; 6240/1783 tok/s;   4670 sec
# 2020-11-07 22:16:40,696 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:16:40,710 INFO number of examples: 555
# 2020-11-07 22:18:17,549 INFO Validation metrics: Bleu: 0.9966,Correct answers 0.8474, State transitions score: 0.8767
# 2020-11-07 22:18:17,550 INFO Validation perplexity: 1.01187
# 2020-11-07 22:18:17,550 INFO Validation accuracy: 99.7892
# 2020-11-07 22:18:28,559 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:18:28,618 INFO number of examples: 3148
# 2020-11-07 22:18:36,883 INFO Step 4200/10000; acc:  99.88; ppl:  1.00; xent: 0.00; lr: 0.00100; 6202/1776 tok/s;   4786 sec
# 2020-11-07 22:18:36,885 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:18:36,900 INFO number of examples: 555
# 2020-11-07 22:20:12,920 INFO Validation metrics: Bleu: 0.9968,Correct answers 0.8484, State transitions score: 0.8741
# 2020-11-07 22:20:12,921 INFO Validation perplexity: 1.01025
# 2020-11-07 22:20:12,922 INFO Validation accuracy: 99.7975
# 2020-11-07 22:20:23,582 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:20:23,637 INFO number of examples: 3148
# 2020-11-07 22:20:32,256 INFO Step 4300/10000; acc:  99.89; ppl:  1.00; xent: 0.00; lr: 0.00100; 6250/1786 tok/s;   4901 sec
# 2020-11-07 22:20:32,258 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:20:32,268 INFO number of examples: 555
# 2020-11-07 22:22:08,554 INFO Validation metrics: Bleu: 0.9971,Correct answers 0.8553, State transitions score: 0.8882
# 2020-11-07 22:22:08,555 INFO Validation perplexity: 1.01045
# 2020-11-07 22:22:08,556 INFO Validation accuracy: 99.8197
# 2020-11-07 22:22:19,199 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:22:19,256 INFO number of examples: 3148
# 2020-11-07 22:22:27,777 INFO Step 4400/10000; acc:  99.87; ppl:  1.00; xent: 0.00; lr: 0.00100; 6222/1784 tok/s;   5017 sec
# 2020-11-07 22:22:27,779 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:22:27,788 INFO number of examples: 555
# 2020-11-07 22:24:06,708 INFO Validation metrics: Bleu: 0.9970,Correct answers 0.8570, State transitions score: 0.8807
# 2020-11-07 22:24:06,710 INFO Validation perplexity: 1.01026
# 2020-11-07 22:24:06,710 INFO Validation accuracy: 99.8086
# 2020-11-07 22:24:17,329 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:24:17,386 INFO number of examples: 3148
# 2020-11-07 22:24:26,370 INFO Step 4500/10000; acc:  99.88; ppl:  1.00; xent: 0.00; lr: 0.00100; 6078/1739 tok/s;   5135 sec
# 2020-11-07 22:24:26,372 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:24:26,383 INFO number of examples: 555
# 2020-11-07 22:26:03,764 INFO Validation metrics: Bleu: 0.9975,Correct answers 0.8550, State transitions score: 0.8942
# 2020-11-07 22:26:03,765 INFO Validation perplexity: 1.00997
# 2020-11-07 22:26:03,765 INFO Validation accuracy: 99.8391
# 2020-11-07 22:26:14,031 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:26:14,097 INFO number of examples: 3148
# 2020-11-07 22:26:23,133 INFO Step 4600/10000; acc:  99.89; ppl:  1.00; xent: 0.00; lr: 0.00100; 6181/1767 tok/s;   5252 sec
# 2020-11-07 22:26:23,135 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:26:23,148 INFO number of examples: 555
# 2020-11-07 22:28:01,231 INFO Validation metrics: Bleu: 0.9946,Correct answers 0.8571, State transitions score: 0.8817
# 2020-11-07 22:28:01,232 INFO Validation perplexity: 1.00994
# 2020-11-07 22:28:01,232 INFO Validation accuracy: 99.8336
# 2020-11-07 22:28:11,370 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:28:11,430 INFO number of examples: 3148
# 2020-11-07 22:28:20,664 INFO Step 4700/10000; acc:  99.89; ppl:  1.00; xent: 0.00; lr: 0.00100; 6141/1754 tok/s;   5370 sec
# 2020-11-07 22:28:20,666 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:28:20,678 INFO number of examples: 555
# 2020-11-07 22:29:58,137 INFO Validation metrics: Bleu: 0.9966,Correct answers 0.8446, State transitions score: 0.8738
# 2020-11-07 22:29:58,138 INFO Validation perplexity: 1.01053
# 2020-11-07 22:29:58,139 INFO Validation accuracy: 99.7975
# 2020-11-07 22:30:08,493 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:30:08,552 INFO number of examples: 3148
# 2020-11-07 22:30:17,986 INFO Step 4800/10000; acc:  99.89; ppl:  1.00; xent: 0.00; lr: 0.00100; 6156/1758 tok/s;   5487 sec
# 2020-11-07 22:30:17,988 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:30:18,000 INFO number of examples: 555
# 2020-11-07 22:31:55,713 INFO Validation metrics: Bleu: 0.9972,Correct answers 0.8545, State transitions score: 0.8765
# 2020-11-07 22:31:55,714 INFO Validation perplexity: 1.00892
# 2020-11-07 22:31:55,714 INFO Validation accuracy: 99.8225
# 2020-11-07 22:32:05,245 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:32:05,302 INFO number of examples: 3148
# 2020-11-07 22:32:15,139 INFO Step 4900/10000; acc:  99.90; ppl:  1.00; xent: 0.00; lr: 0.00100; 6162/1761 tok/s;   5604 sec
# 2020-11-07 22:32:15,140 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:32:15,156 INFO number of examples: 555
# 2020-11-07 22:33:53,224 INFO Validation metrics: Bleu: 0.9970,Correct answers 0.8507, State transitions score: 0.8861
# 2020-11-07 22:33:53,225 INFO Validation perplexity: 1.01105
# 2020-11-07 22:33:53,226 INFO Validation accuracy: 99.8141
# 2020-11-07 22:34:03,004 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:34:03,062 INFO number of examples: 3148
# 2020-11-07 22:34:12,901 INFO Step 5000/10000; acc:  99.90; ppl:  1.00; xent: 0.00; lr: 0.00100; 6125/1752 tok/s;   5722 sec
# 2020-11-07 22:34:12,903 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:34:12,914 INFO number of examples: 555
# 2020-11-07 22:35:50,180 INFO Validation metrics: Bleu: 0.9968,Correct answers 0.8515, State transitions score: 0.8809
# 2020-11-07 22:35:50,181 INFO Validation perplexity: 1.01071
# 2020-11-07 22:35:50,182 INFO Validation accuracy: 99.8086
# 2020-11-07 22:35:50,194 INFO Saving checkpoint model_step_5000.pt
# 2020-11-07 22:35:59,602 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:35:59,662 INFO number of examples: 3148
# 2020-11-07 22:36:09,829 INFO Step 5100/10000; acc:  99.89; ppl:  1.00; xent: 0.00; lr: 0.00100; 6154/1763 tok/s;   5839 sec
# 2020-11-07 22:36:09,831 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:36:09,851 INFO number of examples: 555
# 2020-11-07 22:37:47,509 INFO Validation metrics: Bleu: 0.9973,Correct answers 0.8561, State transitions score: 0.8838
# 2020-11-07 22:37:47,510 INFO Validation perplexity: 1.00954
# 2020-11-07 22:37:47,510 INFO Validation accuracy: 99.8363
# 2020-11-07 22:37:56,761 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:37:56,821 INFO number of examples: 3148
# 2020-11-07 22:38:07,307 INFO Step 5200/10000; acc:  99.92; ppl:  1.00; xent: 0.00; lr: 0.00100; 6140/1756 tok/s;   5956 sec
# 2020-11-07 22:38:07,309 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:38:07,321 INFO number of examples: 555
# 2020-11-07 22:39:45,408 INFO Validation metrics: Bleu: 0.9967,Correct answers 0.8571, State transitions score: 0.8817
# 2020-11-07 22:39:45,409 INFO Validation perplexity: 1.01128
# 2020-11-07 22:39:45,409 INFO Validation accuracy: 99.8003
# 2020-11-07 22:39:54,804 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:39:54,860 INFO number of examples: 3148
# 2020-11-07 22:40:05,317 INFO Step 5300/10000; acc:  99.91; ppl:  1.00; xent: 0.00; lr: 0.00100; 6126/1748 tok/s;   6074 sec
# 2020-11-07 22:40:05,319 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:40:05,329 INFO number of examples: 555
# 2020-11-07 22:41:42,050 INFO Validation metrics: Bleu: 0.9975,Correct answers 0.8532, State transitions score: 0.8953
# 2020-11-07 22:41:42,051 INFO Validation perplexity: 1.01016
# 2020-11-07 22:41:42,052 INFO Validation accuracy: 99.853
# 2020-11-07 22:41:50,694 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:41:50,751 INFO number of examples: 3148
# 2020-11-07 22:42:01,498 INFO Step 5400/10000; acc:  99.90; ppl:  1.00; xent: 0.00; lr: 0.00100; 6191/1773 tok/s;   6191 sec
# 2020-11-07 22:42:01,500 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:42:01,513 INFO number of examples: 555
# 2020-11-07 22:43:39,645 INFO Validation metrics: Bleu: 0.9968,Correct answers 0.8517, State transitions score: 0.8821
# 2020-11-07 22:43:39,646 INFO Validation perplexity: 1.01071
# 2020-11-07 22:43:39,646 INFO Validation accuracy: 99.8141
# 2020-11-07 22:43:48,195 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:43:48,252 INFO number of examples: 3148
# 2020-11-07 22:43:58,915 INFO Step 5500/10000; acc:  99.92; ppl:  1.00; xent: 0.00; lr: 0.00100; 6127/1756 tok/s;   6308 sec
# 2020-11-07 22:43:58,917 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:43:58,932 INFO number of examples: 555
# 2020-11-07 22:45:37,296 INFO Validation metrics: Bleu: 0.9966,Correct answers 0.8543, State transitions score: 0.8846
# 2020-11-07 22:45:37,297 INFO Validation perplexity: 1.01138
# 2020-11-07 22:45:37,297 INFO Validation accuracy: 99.8114
# 2020-11-07 22:45:45,713 INFO Loading dataset from processed/SimQA.train.0.pt
# 2020-11-07 22:45:45,769 INFO number of examples: 3148
# 2020-11-07 22:45:56,696 INFO Step 5600/10000; acc:  99.92; ppl:  1.00; xent: 0.00; lr: 0.00100; 6139/1751 tok/s;   6426 sec
# 2020-11-07 22:45:56,698 INFO Loading dataset from processed/SimQA.valid.0.pt
# 2020-11-07 22:45:56,709 INFO number of examples: 555
# 2020-11-07 22:47:36,197 INFO Validation metrics: Bleu: 0.9946,Correct answers 0.8516, State transitions score: 0.8825
# 2020-11-07 22:47:36,198 INFO Validation perplexity: 1.01053
# 2020-11-07 22:47:36,199 INFO Validation accuracy: 99.8252
